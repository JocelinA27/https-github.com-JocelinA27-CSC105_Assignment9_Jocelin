# %%
import pandas as pd
from matplotlib import pyplot as plt

# %%
df = pd.read_csv("Data/healthcare_data.csv")

df
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 1         1002              Jane Doe   62  Female         B-       Diabetes
# 2         1003        Robert Johnson   35    Male         O+         Cancer
# 3         1004          Susan Wilson   78  Female         A-  Heart Disease
# 4         1005         Michael Brown   55    Male        AB+         Asthma
# 5         1006           Lisa Miller   30  Female         B+   Hypertension
# 6         1007           James Davis   48    Male         O-       Diabetes
# 7         1008          Karen Harris   65  Female        AB-         Cancer
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 9         1010           Linda Smith   42  Female         O+         Asthma
# 10        1011           William Lee   33    Male        AB+   Hypertension
# ...

# %%
df.index
# Out:
# RangeIndex(start=0, stop=50, step=1)

# %%
df[['Age']]
# Out:
#     Age
# 0    45
# 1    62
# 2    35
# 3    78
# 4    55
# 5    30
# 6    48
# 7    65
# 8    72
# 9    42
# 10   33
# 11   70
# 12   55
# 13   51
# 14   44
# 15   62
# 16   29
# 17   40
# 18   67
# 19   49
# 20   38
# 21   54
# 22   58
# 23   41
# 24   47
# 25   35
# 26   60
# 27   53
# 28   49
# 29   56
# 30   44
# 31   65
# 32   30
# 33   70
# 34   35
# 35   52
# 36   57
# 37   43
# 38   62
# 39   41
# 40   46
# 41   51
# 42   55
# 43   42
# 44   59
# 45   64
# 46   40
# 47   39
# 48   34
# 49   47

# %%
df[['Age']].max()
# Out:
# Age    78
# dtype: int64

# %%
Age = df[['Age']]

# %%
plt.style.use("fivethirtyeight")

plt.hist(Age)

plt.hist(Age,bins=10,color="b",edgecolor="black")

plt.title("Distrubution of Patient Ages")
plt.xlabel("Age")
plt.ylabel("Frequency")

plt.tight_layout()
plt.grid(True)
plt.show()

# %%
df[(df['Gender'] == "Male")]
# Out:
#     Patient_ID          Patient_Name  Age Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45   Male         A+   Hypertension
# 2         1003        Robert Johnson   35   Male         O+         Cancer
# 4         1005         Michael Brown   55   Male        AB+         Asthma
# 6         1007           James Davis   48   Male         O-       Diabetes
# 8         1009          David Wilson   72   Male         A+  Heart Disease
# 10        1011           William Lee   33   Male        AB+   Hypertension
# 12        1013        Richard Taylor   55   Male         O+       Diabetes
# 14        1015         Charles Jones   44   Male        AB-  Heart Disease
# 16        1017        Robert Jackson   29   Male         O-   Hypertension
# 18        1019      Michael Williams   67   Male        AB+  Heart Disease
# 20        1021           John Wilson   38   Male         O+   Hypertension
# ...

# %% [markdown]
# ### **50%**

# %%
df[(df['Diagnosis'] == "Cancer")]
# Out:
#     Patient_ID      Patient_Name  Age  Gender Blood_Type Diagnosis  \
# 2         1003    Robert Johnson   35    Male         O+    Cancer
# 7         1008      Karen Harris   65  Female        AB-    Cancer
# 11        1012        Mary Brown   70  Female         B-    Cancer
# 15        1016      Linda Wilson   62  Female         A+    Cancer
# 22        1023     Daniel Harris   58    Male         A+    Cancer
# 27        1028      Susan Taylor   53  Female         O+    Cancer
# 32        1033    William Harris   30    Male        AB+    Cancer
# 37        1038     Laura Johnson   43  Female        AB+    Cancer
# 42        1043     Matthew Davis   55    Male         O+    Cancer
# 47        1048  Patricia Jackson   39  Female         A+    Cancer
#
#     Treatment_Cost
# 2           5500.0
# 7              NaN
# 11             NaN
# 15          5900.0
# 22          6400.0
# 27          6100.5
# 32             NaN
# 37          6700.0
# 42             NaN
# 47          6700.5

# %%
df[(df['Age'] >= 60) & df['Treatment_Cost']]
# Out:
#     Patient_ID      Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 1         1002          Jane Doe   62  Female         B-       Diabetes
# 3         1004      Susan Wilson   78  Female         A-  Heart Disease
# 8         1009      David Wilson   72    Male         A+  Heart Disease
# 15        1016      Linda Wilson   62  Female         A+         Cancer
# 26        1027      Joseph Brown   60    Male         A-       Diabetes
# 31        1032    Linda Martinez   65  Female         B+       Diabetes
# 38        1039     Richard Davis   62    Male         O-  Heart Disease
# 45        1046  Elizabeth Wilson   64  Female         O-   Hypertension
#
#     Treatment_Cost
# 1           800.75
# 3          2700.25
# 8          3200.00
# 15         5900.00
# 26          880.25
# 31          850.25
# 38         3300.00
# 45         1125.25

# %%
average_treatment_cost = df[df['Age'] >= 60]['Treatment_Cost'].mean()
print(average_treatment_cost)
# Out:
# 2344.59375

# %%
df[['Blood_Type']]
# Out:
#    Blood_Type
# 0          A+
# 1          B-
# 2          O+
# 3          A-
# 4         AB+
# 5          B+
# 6          O-
# 7         AB-
# 8          A+
# 9          O+
# 10        AB+
# 11         B-
# 12         O+
# 13         A-
# 14        AB-
# 15         A+
# 16         O-
# 17         B+
# 18        AB+
# 19         A-
# 20         O+
# 21         B-
# 22         A+
# 23         O-
# 24        AB+
# 25         B+
# 26         A-
# 27         O+
# 28        AB-
# 29         A+
# 30         O-
# 31         B+
# 32        AB+
# 33         A-
# 34         O+
# 35         A+
# 36         B-
# 37        AB+
# 38         O-
# 39        AB-
# 40         A+
# 41         B+
# 42         O+
# 43         A-
# 44        AB+
# 45         O-
# 46         B-
# 47         A+
# 48         O+
# 49        AB-

# %%
df.sort_values('Blood_Type')
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 15        1016          Linda Wilson   62  Female         A+         Cancer
# 22        1023         Daniel Harris   58    Male         A+         Cancer
# 29        1030           Mary Wilson   56  Female         A+         Asthma
# 35        1036           Karen Smith   52  Female         A+   Hypertension
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 47        1048      Patricia Jackson   39  Female         A+         Cancer
# 40        1041  Christopher Martinez   46    Male         A+   Hypertension
# 43        1044           Susan Smith   42  Female         A-  Heart Disease
# 19        1020         Sarah Johnson   49  Female         A-         Asthma
# 33        1034             Sarah Lee   70  Female         A-  Heart Disease
# ...

# %%
df[(df['Blood_Type'] == "A+") & ['Treatment_Cost']]
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 15        1016          Linda Wilson   62  Female         A+         Cancer
# 22        1023         Daniel Harris   58    Male         A+         Cancer
# 29        1030           Mary Wilson   56  Female         A+         Asthma
# 35        1036           Karen Smith   52  Female         A+   Hypertension
# 40        1041  Christopher Martinez   46    Male         A+   Hypertension
# 47        1048      Patricia Jackson   39  Female         A+         Cancer
#
#     Treatment_Cost
# 0           1200.5
# 8           3200.0
# 15          5900.0
# 22          6400.0
# 29           480.0
# 35             NaN
# 40          1280.5
# 47          6700.5

# %%
df[(df['Blood_Type'] == "A+") & ['Treatment_Cost']]
# Out:
#     Patient_ID          Patient_Name  Age  Gender Blood_Type      Diagnosis  \
# 0         1001            John Smith   45    Male         A+   Hypertension
# 8         1009          David Wilson   72    Male         A+  Heart Disease
# 15        1016          Linda Wilson   62  Female         A+         Cancer
# 22        1023         Daniel Harris   58    Male         A+         Cancer
# 29        1030           Mary Wilson   56  Female         A+         Asthma
# 35        1036           Karen Smith   52  Female         A+   Hypertension
# 40        1041  Christopher Martinez   46    Male         A+   Hypertension
# 47        1048      Patricia Jackson   39  Female         A+         Cancer
#
#     Treatment_Cost
# 0           1200.5
# 8           3200.0
# 15          5900.0
# 22          6400.0
# 29           480.0
# 35             NaN
# 40          1280.5
# 47          6700.5

# %%
df.groupby(['Blood_Type'])[['Treatment_Cost']].mean()
# Out:
#             Treatment_Cost
# Blood_Type
# A+             3594.500000
# A-             1470.300000
# AB+            2232.687500
# AB-            1923.833333
# B+              860.250000
# B-              860.750000
# O+             2870.125000
# O-             1935.250000

# %%
df2 = df.groupby(['Blood_Type'])[['Treatment_Cost']].mean()

# %%
df[df['Blood_Type'] == "A+"].groupby('Blood_Type')[['Treatment_Cost']].max()
# Out:
#             Treatment_Cost
# Blood_Type
# A+                  6700.5

# %%
df.groupby(['Gender'])[['Age']].mean()
# Out:
#           Age
# Gender
# Female  52.08
# Male    47.88

# %%
df.groupby(['Diagnosis'])[['Age']].mean()
# Out:
# Empty DataFrame
# Columns: [Age]
# Index: []
